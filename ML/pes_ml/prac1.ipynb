# %%
import pandas as pd
df = pd.read_csv('Salaries.csv')
df.iloc[300:306, :]
# Out:
#      Unnamed: 0  rank discipline  yrs.since.phd  yrs.service   sex  salary
# 300         301  Prof          A             39           36  Male   88600
# 301         302  Prof          A             27           16  Male  127100
# 302         303  Prof          A             28           13  Male  170500
# 303         304  Prof          A             14            4  Male  105260
# 304         305  Prof          A             46           44  Male  144050
# 305         306  Prof          A             33           31  Male  111350

# %% [markdown]
# # iloc is used to fetch data from particular rows and columns left side of comma is rows and right side is column

# %%
df.index
# Out:
# RangeIndex(start=0, stop=397, step=1)

# %%
df.set_index('rank')
#insted of index which was starting from first column but we can set the index from rank that start from rank now
# Out:
#           Unnamed: 0 discipline  yrs.since.phd  yrs.service   sex  salary
# rank
# Prof               1          B             19           18  Male  139750
# Prof               2          B             20           16  Male  173200
# AsstProf           3          B              4            3  Male   79750
# Prof               4          B             45           39  Male  115000
# Prof               5          B             40           41  Male  141500
# ...              ...        ...            ...          ...   ...     ...
# Prof             393          A             33           30  Male  103106
# Prof             394          A             31           19  Male  150564
# Prof             395          A             42           25  Male  101738
# Prof             396          A             25           15  Male   95329
# AsstProf         397          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %%
k = df.groupby('yrs.service')
k1 = k.get_group(12)
k1
#same as dbms we can group by requirements
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service   sex  \
# 66           67       Prof          B             22           12  Male
# 96           97  AssocProf          B             17           12  Male
# 150         151       Prof          B             14           12  Male
# 252         253       Prof          A             31           12  Male
# 337         338       Prof          B             13           12  Male
#
#      salary
# 66   101000
# 96    95611
# 150  128148
# 252  132000
# 337  145000

# %%
df['New'] = range(0,397)

# %%
df.head()
# Out:
#    Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary  \
# 0           1      Prof          B             19           18  Male  139750
# 1           2      Prof          B             20           16  Male  173200
# 2           3  AsstProf          B              4            3  Male   79750
# 3           4      Prof          B             45           39  Male  115000
# 4           5      Prof          B             40           41  Male  141500
#
#    New
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4

# %% [markdown]
# df['salary'].value_counts()
# #value count tell the number of categories in a column

# %%
df[(df['rank'] == 'Prof') & (df['salary'] >= max(df['salary']))]
# Out:
#     Unnamed: 0  rank discipline  yrs.since.phd  yrs.service   sex  salary  New
# 43          44  Prof          B             38           38  Male  231545   43

# %% [markdown]
# # matplotlib for graphs

# %%
import matplotlib.pyplot as plt
df['rank'].value_counts().plot.bar(color=['c', 'b', 'r'])
plt.ylim(0, 500)
#label of xaxis
plt.xlabel("category")
#label of y axis
plt.ylabel("number of ranks")
plt.grid()
plt.show()

# %% [markdown]
# # new

# %%
import pandas as pd
import matplotlib.pyplot
df = pd.read_csv('Salaries.csv')
df['rank'].value_counts().plot.bar(color = ['r', 'g', 'b'])
# Out:
# <Axes: xlabel='rank'>

# %%
salary_count = df['rank'].value_counts()
plt.pie(salary_count)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('Salaries.csv')
service = df['yrs.service']
phd = df['yrs.since.phd']
plt.scatter(service, phd)

# %%
salary = df['salary']
phd = df['yrs.since.phd']
plt.scatter(salary, phd, marker='+', color=['b'])

# %%
#df.corr gives the correlation between the columns this can be done by using scatter plt and make use of correlation
df[['yrs.service', 'yrs.since.phd', 'salary' ]].corr()
# Out:
#                yrs.service  yrs.since.phd    salary
# yrs.service       1.000000       0.909649  0.334745
# yrs.since.phd     0.909649       1.000000  0.419231
# salary            0.334745       0.419231  1.000000

# %%
#line graph is good for timeline it shows how the price has change for a period of time.
df['salary'].plot(color=['r'])
# Out:
# <Axes: >

# %%
rank = df['rank'].value_counts()
salary = df['salary'].value_counts()

# %%
import seaborn as sb
sb.histplot(data= df, x = 'salary', hue='sex')
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
# sb.scatterplot(data= df, x='yrs.service', y='salary', hue='sex')
sb.countplot(data=df, x='yrs.service',  hue='sex')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # sb.scatterplot(data= df, x='yrs.service', y='salary', hue='sex')
# ----> 2 sb.countplot(data=df, x='yrs.service',  hue='sex')
#       3 plt.show()
#
# NameError: name 'sb' is not defined

# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('Salaries.csv')
df
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0             1      Prof          B             19           18  Male  139750
# 1             2      Prof          B             20           16  Male  173200
# 2             3  AsstProf          B              4            3  Male   79750
# 3             4      Prof          B             45           39  Male  115000
# 4             5      Prof          B             40           41  Male  141500
# ..          ...       ...        ...            ...          ...   ...     ...
# 392         393      Prof          A             33           30  Male  103106
# 393         394      Prof          A             31           19  Male  150564
# 394         395      Prof          A             42           25  Male  101738
# 395         396      Prof          A             25           15  Male   95329
# 396         397  AsstProf          A              8            4  Male   81035
#
# [397 rows x 7 columns]

# %%
sb.countplot(data= df, x = 'rank', hue='sex')
# Out:
# <Axes: xlabel='rank', ylabel='count'>

# %%
sb.jointplot(data= df, x='yrs.service', y= 'salary', hue='sex', kind='hist')

# %%
#scatter plot with regression line is called regression plot
sb.regplot(data= df, x= 'yrs.service', y= 'salary')
# Out:
# <Axes: xlabel='yrs.service', ylabel='salary'>

# %%
sb.barplot(data = df, x = 'rank', y='salary', hue='sex')
# Out:
# <Axes: xlabel='rank', ylabel='salary'>

# %%
sb.catplot(data = df, x= 'rank', y= 'salary', hue='sex', kind='violin')
#other attributes in kind attirbute is swarm box strip  and violin where the mid line is median

# %%
sb.lineplot(data=df, x='yrs.since.phd', y='salary')
# Out:
# <Axes: xlabel='yrs.since.phd', ylabel='salary'>

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df.corr()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'salary'
#
# The above exception was the direct cause of the following exception:
#
# ...
