# %%
from bing_image_downloader.downloader import download

download('dog', limit=50, output_dir='dog-train', verbose=False)
download('cat', limit=50, output_dir='cat-train',  verbose=False)
# Out:
# [%] Downloading Images to /home/pilli007/Documents/pes-sem2/ML/pes_ml/webscrappiing/dog-train/dog
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://avada.theme-fusion.com/veterinarian/wp-content/uploads/sites/80/2016/11/pets_big.png
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://images.hdqwalls.com/wallpapers/dog-nose.jpg
# [!] Issue getting: https://images.hdqwalls.com/wallpapers/dog-nose.jpg
# [!] Error:: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1007)>
# [%] Downloading Image #2 from https://images2.alphacoders.com/467/467417.jpg
# [!] Issue getting: https://images2.alphacoders.com/467/467417.jpg
# [!] Error:: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1007)>
# ...

# %%
download('single dog', limit=10, output_dir='test-dog', verbose=False)
download('single cat', limit=10, output_dir='test-cat', verbose=False)
# Out:
# [%] Downloading Images to /home/pilli007/Documents/pes-sem2/ML/pes_ml/webscrappiing/test-dog/single dog
# [Error]Invalid image, not saving http://secondhandmutts.org/wp-content/uploads/2013/05/singlemingle.jpg
#
# [!] Issue getting: http://secondhandmutts.org/wp-content/uploads/2013/05/singlemingle.jpg
# [!] Error:: Invalid image, not saving http://secondhandmutts.org/wp-content/uploads/2013/05/singlemingle.jpg
#
# [!] Issue getting: https://i.ytimg.com/vi/FnhMrgZfZu4/maxresdefault.jpg
# [!] Error:: <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1007)>
#
#
# [%] Done. Downloaded 10 images.
# [%] Downloading Images to /home/pilli007/Documents/pes-sem2/ML/pes_ml/webscrappiing/test-cat/single cat
# [Error]Invalid image, not saving https://hotelkitty.co.uk/wp-content/uploads/2016/05/single-cat.jpg
#
# [!] Issue getting: https://hotelkitty.co.uk/wp-content/uploads/2016/05/single-cat.jpg
# ...

# %%
#using text preprocessing NLP, pillow for image processing
#use im read to convert image to matrix

# %%
from skimage.io import imread_collection

catdir = '/home/pilli007/Documents/pes-sem2/ML/pes_ml/webscrappiing/cat-train'
dogdir = '/home/pilli007/Documents/pes-sem2/ML/pes_ml/webscrappiing/dog-train'
